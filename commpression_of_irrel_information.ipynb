# %% [markdown]
# # Information Bottleneck theory for Deep Learning

# %% [markdown]
# This is a demonstration of the information bottleneck theory for deep learning, introduced by Naftali Tishby. Here I tried to reproduce the main results in their recent paper [Opening the black box of Deep Neural Networks via Information](https://arxiv.org/pdf/1703.00810.pdf).

# %% [markdown]
# ## Data generation

# %% [markdown]
# Feature $X$ - random binary vector of dim $10$
#
# Target $Y$ - binary
#
# $Y$ depends only on $X_{\text{rel}} = (X_6, \dots, X_9)$ i.e. $\mathbb{P}(Y|X) = \mathbb{P}(Y|X_{\text{rel}})$
#
# Denote remaining variables as $X_{\text{irrel}}$
#
# **What happens with** $I(T, X_{\text{rel}})$ **and** $I(T, X_{\text{irrel}})$**?**

# %%
import numpy as np
from random import randint, seed

# %%
n_train_samples = 50000 # number of train samples
n_test_samples = 10000 # number of test samples

groups = np.append(np.zeros(8),np.ones(8)) # 16 groups
np.random.seed(1234)
np.random.shuffle(groups)
p_noise_y = 0.1
p_noise_x = 0.0
irrel_idx = [0, 1, 2, 3, 4, 5]
rel_idx = [6, 7, 8, 9]
def bin_noise(x, p):
    return x if np.random.rand() > 2 * p else np.random.randint(0, 1)

# generate samples
seed(1234)
def generate_samples(n_samples):
    x_data = np.zeros((n_samples, 10)) # inputs
    x_int = np.zeros(n_samples) # integers representing the inputs
    y_data = np.zeros((n_samples, 2)) # outputs
    
    for i in range(n_samples):
        random_int = randint(0, 1023)
        x_data[i,:] = [bin_noise(int(b), p_noise_x) for b in list("{0:b}".format(random_int).zfill(10))]
        x_int[i] = np.sum([x_data[i, k] * (2 ** (9 - k)) for k in range(10)])
        y_data[i,0] = bin_noise(groups[random_int % 16], p_noise_y)
        y_data[i,1] = 1 - y_data[i,0]
        
    return x_data, y_data, x_int

x_train, y_train, x_train_int = generate_samples(n_train_samples) # training dataset
x_test, y_test, _ = generate_samples(n_test_samples) # testing dataset

# %% [markdown]
# ## Neural network

# %% [markdown]
# Then we are going to build a fully-connected neural networks with 3 hidden layers, which have 8, 6 and 4 neurons respectively. First let's define a fully-connected layer and a output layer using Tensorflow:

# %%
import tensorflow as tf

def fully_conn(tensor, n_outputs, name):
    size = tensor.get_shape().as_list()[1]
    
    # weight and bias tensor
    weight = tf.Variable(tf.truncated_normal([size, n_outputs]))
    bias = tf.Variable(tf.zeros([n_outputs]))
    
    # fully-connected layer
    tensor = tf.matmul(tensor, weight)
    bias = tf.nn.bias_add(tensor, bias)
    
    # hyperbolic tangent activation
    tensor = tf.tanh(tensor, name=name)
    
    return tensor

# %% [markdown]
# For the output layer, there would be no activation function:

# %%
def output(tensor, n_outputs):
    size = tensor.get_shape().as_list()[1]
    
    # weight and bias tensor
    weight = tf.Variable(tf.truncated_normal([size, n_outputs]))
    bias = tf.Variable(tf.zeros([n_outputs]))
    
    # fully-connected layer
    tensor = tf.matmul(tensor, weight)
    bias = tf.nn.bias_add(tensor, bias)
    
    return tensor

# %% [markdown]
# Now we could use the building blocks defined above to define a multilayer perceptron (MLP) model:

# %%
def mlp(x, n_neurons): # x is the input layer    
    # hidden layers
    hidden = x
    for n in range(len(n_neurons)):
        hidden = fully_conn(hidden, n_neurons[n], 'hidden%s' % (n+1))
    
    # output layer
    y = output(hidden, 2)
    
    return y

# %% [markdown]
# It's time to build our network!

# %%
def build_network(hidden_layer_neurons):
    global x, y, logits, cost, optimizer, accuracy
    
    tf.reset_default_graph()
    x = tf.placeholder(tf.float32, (None, 10), name='x')
    y = tf.placeholder(tf.float32, (None, 2), name='y')

    tf.set_random_seed(12345)
    logits = mlp(x, hidden_layer_neurons)
    logits = tf.identity(logits, name='logits')

    # cross-entropy coss function
    cost = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=y), name='cost')
    
    # optimizer
    optimizer = tf.train.GradientDescentOptimizer(0.1).minimize(cost)
    
    # accuracy
    correct_predictions = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_predictions, tf.float32), name='accuracy')
    
def print_out_summary(sess, epoch):
    acc, loss = sess.run([accuracy, cost], feed_dict={x: x_test, y: y_test})
    print('Epoch {:>4}:  Testing accuracy {:>.4f} - Testing loss {:>.4f}'.format(epoch, acc, loss))

build_network([8,6,4]) # 3 hidden layers with 8, 6 and 4 neurons respectively

# %% [markdown]
# Let's first train the network without calculating the mutual information to make sure we have the correct results.

# %%
n_epochs = 2000

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer()) # initialization
    
    for epoch in range(n_epochs):
        sess.run(optimizer, feed_dict={x: x_train, y: y_train})
        if epoch % 100 == 0: print_out_summary(sess, epoch)
# Out:
# Epoch    0:  Testing accuracy 0.4298 - Testing loss 1.1367
# Epoch  100:  Testing accuracy 0.5993 - Testing loss 0.6875
# Epoch  200:  Testing accuracy 0.6051 - Testing loss 0.6700
# Epoch  300:  Testing accuracy 0.6187 - Testing loss 0.6593
# Epoch  400:  Testing accuracy 0.6238 - Testing loss 0.6455
# Epoch  500:  Testing accuracy 0.6046 - Testing loss 0.6291
# Epoch  600:  Testing accuracy 0.6189 - Testing loss 0.6110
# Epoch  700:  Testing accuracy 0.6144 - Testing loss 0.5865
# Epoch  800:  Testing accuracy 0.6367 - Testing loss 0.5517
# Epoch  900:  Testing accuracy 0.6786 - Testing loss 0.5142
# Epoch 1000:  Testing accuracy 0.7175 - Testing loss 0.4821
# Epoch 1100:  Testing accuracy 0.7429 - Testing loss 0.4595
# Epoch 1200:  Testing accuracy 0.7583 - Testing loss 0.4461
# Epoch 1300:  Testing accuracy 0.7632 - Testing loss 0.4365
# Epoch 1400:  Testing accuracy 0.7629 - Testing loss 0.4280
# Epoch 1500:  Testing accuracy 0.7543 - Testing loss 0.4191
# Epoch 1600:  Testing accuracy 0.7918 - Testing loss 0.3993
# Epoch 1700:  Testing accuracy 0.8486 - Testing loss 0.3396
# Epoch 1800:  Testing accuracy 0.8656 - Testing loss 0.3251
# Epoch 1900:  Testing accuracy 0.8725 - Testing loss 0.3149

# %% [markdown]
# The training is pretty successfully, at about 1600 steps we reached 100% accuracy for the test dataset, which is what we would expect for a simple dataset like this.

# %% [markdown]
# ## Mutual information

# %% [markdown]
# Now we are ready to explore the information bottleneck theory for our network. To estimate the mutual information between all the hidden layers and intput/output layers, we could binned the output activations as stated in the paper  (here we choose 30 bins, the same as in the paper), so that the hidden layer random variables $T_i$ (each $i$ corresponds to one hidden layer) would be discrete. Then, we will be able to estimate the joint distribution $P(X,T_i)$ and $P(T_i,Y)$, and use them to calculate the encoder mutual information (between input $X$ and hidden layer $T_i$)
# \begin{equation}
#     I(X;T_i) = \sum_{x\in X, t\in T_i}P(x,t)\log\Big(\frac{P(x,t)}{P(x)P(t)}\Big)
# \end{equation}
#
# and decoder mutual information (between hidden layer $T_i$ and desired output $Y$, note that it is not the model output $\widehat{Y}$)
# \begin{equation}
#     I(T_i;Y) = \sum_{t\in T_i, y\in Y}P(t,y)\log\Big(\frac{P(t,y)}{P(t)P(y)}\Big).
# \end{equation}

# %%
from collections import Counter

def bin2num(x, idx):
    return np.sum([x[k] * (2 ** (9 - k)) for k in idx])

def calc_mutual_information(hidden, xs='all'):
    assert(xs in ['all', 'rel', 'irrel'])
    xs = {'all':list(range(10)), 'rel': rel_idx, 'irrel': irrel_idx}[xs]
    n_neurons = hidden.shape[1]
  
    # discretization 
    n_bins = 30
    bins = np.linspace(-1, 1, n_bins+1)
    indices = np.digitize(hidden, bins)
    
    # initialize pdfs
    pdf_x = Counter(); pdf_y = Counter(); pdf_t = Counter(); pdf_xt = Counter(); pdf_yt = Counter()

    for i in range(n_train_samples):
        pdf_x[bin2num(x_train[i], xs)] += 1/float(n_train_samples)
        pdf_y[y_train[i,0]] += 1/float(n_train_samples)      
        pdf_xt[(bin2num(x_train[i], xs),)+tuple(indices[i,:])] += 1/float(n_train_samples)
        pdf_yt[(y_train[i,0],)+tuple(indices[i,:])] += 1/float(n_train_samples)
        pdf_t[tuple(indices[i,:])] += 1/float(n_train_samples)
    
    # calcuate encoder mutual information I(X;T)
    mi_xt = 0
    for i in pdf_xt:
        # P(x,t), P(x) and P(t)
        p_xt = pdf_xt[i]; p_x = pdf_x[i[0]]; p_t = pdf_t[i[1:]]
        # I(X;T)
        mi_xt += p_xt * np.log(p_xt / p_x / p_t)
 
    # calculate decoder mutual information I(T;Y)
    mi_ty = 0
    for i in pdf_yt:
        # P(t,y), P(t) and P(y)
        p_yt = pdf_yt[i]; p_t = pdf_t[i[1:]]; p_y = pdf_y[i[0]]
        # I(X;T)
        mi_ty += p_yt * np.log(p_yt / p_t / p_y)
            
    return mi_xt, mi_ty

# get mutual information for all hidden layers
def get_mutual_information(hiddens, xs='all'):
    mi_xt_list = []; mi_ty_list = []
    for hidden in hiddens:
        mi_xt, mi_ty = calc_mutual_information(hidden, xs=xs)
        mi_xt_list.append(mi_xt)
        mi_ty_list.append(mi_ty)
    return mi_xt_list, mi_ty_list

# %% [markdown]
# We are now able to estimate the mutual information while training the network. We'll save the mutual information for later use.

# %%
def get_hidden_layers(names):
    hidden_layers = []
    for name in names:
        hidden_layers.append(tf.get_default_graph().get_tensor_by_name("%s:0" % name))
    return hidden_layers

# train the neural network and obtain mutual information
def train_with_mi(n_epochs, n_hidden_layers):
    mi_xt_all = []; mi_ty_all = []; epochs = []; mi_xt_rel = []; mi_xt_irrel = []
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer()) # initialization
    
        hidden_layer_names = ['hidden%s' % i for i in range(1,n_hidden_layers+1)]
        for epoch in range(n_epochs):
            _, hidden_layers = sess.run([optimizer,
                                         get_hidden_layers(hidden_layer_names)],
                                        feed_dict={x: x_train, y: y_train})
                        
            if epoch % 100 == 0: print_out_summary(sess, epoch)
                
            if epoch % 100 == 0:
                mi_xt, mi_ty = get_mutual_information(hidden_layers)
                mi_xt_rel_, _ = get_mutual_information(hidden_layers, xs='rel')
                mi_xt_irrel_, _ = get_mutual_information(hidden_layers, xs='irrel')
                mi_xt_all.append(mi_xt)
                mi_xt_rel.append(mi_xt_rel_)
                mi_xt_irrel.append(mi_xt_irrel_)
                mi_ty_all.append(mi_ty)
                epochs.append(epoch)
    
    return np.array(mi_xt_all), np.array(mi_ty_all), np.array(epochs), np.array(mi_xt_rel), np.array(mi_xt_irrel)

n_epochs = 3000
n_hidden_layers = 3
mi_xt_all, mi_ty_all, epochs, mi_xt_rel, mi_xt_irrel = train_with_mi(n_epochs, n_hidden_layers)
# Out:
# Epoch    0:  Testing accuracy 0.5604 - Testing loss 0.9283
# Epoch  100:  Testing accuracy 0.6060 - Testing loss 0.6828
# Epoch  200:  Testing accuracy 0.6126 - Testing loss 0.6664
# Epoch  300:  Testing accuracy 0.6156 - Testing loss 0.6582
# Epoch  400:  Testing accuracy 0.6321 - Testing loss 0.6511
# Epoch  500:  Testing accuracy 0.6433 - Testing loss 0.6406
# Epoch  600:  Testing accuracy 0.6599 - Testing loss 0.6261
# Epoch  700:  Testing accuracy 0.6824 - Testing loss 0.5918
# Epoch  800:  Testing accuracy 0.7565 - Testing loss 0.5024
# Epoch  900:  Testing accuracy 0.7649 - Testing loss 0.4617
# Epoch 1000:  Testing accuracy 0.7781 - Testing loss 0.4403
# Epoch 1100:  Testing accuracy 0.7867 - Testing loss 0.4213
# Epoch 1200:  Testing accuracy 0.8003 - Testing loss 0.4025
# Epoch 1300:  Testing accuracy 0.8092 - Testing loss 0.3865
# Epoch 1400:  Testing accuracy 0.8202 - Testing loss 0.3749
# Epoch 1500:  Testing accuracy 0.8233 - Testing loss 0.3670
# Epoch 1600:  Testing accuracy 0.8265 - Testing loss 0.3611
# Epoch 1700:  Testing accuracy 0.8294 - Testing loss 0.3560
# Epoch 1800:  Testing accuracy 0.8369 - Testing loss 0.3502
# Epoch 1900:  Testing accuracy 0.8429 - Testing loss 0.3419
# Epoch 2000:  Testing accuracy 0.8548 - Testing loss 0.3296
# Epoch 2100:  Testing accuracy 0.8740 - Testing loss 0.3083
# Epoch 2200:  Testing accuracy 0.8904 - Testing loss 0.2819
# Epoch 2300:  Testing accuracy 0.9006 - Testing loss 0.2619
# Epoch 2400:  Testing accuracy 0.9022 - Testing loss 0.2586
# Epoch 2500:  Testing accuracy 0.9022 - Testing loss 0.2569
# Epoch 2600:  Testing accuracy 0.9022 - Testing loss 0.2557
# Epoch 2700:  Testing accuracy 0.9022 - Testing loss 0.2548
# Epoch 2800:  Testing accuracy 0.9022 - Testing loss 0.2541
# Epoch 2900:  Testing accuracy 0.9022 - Testing loss 0.2535

# %% [markdown]
# ## Visualization

# %% [markdown]
# Below is a movie showing the evolution of the hidden layers with the training epochs in the information plane. We can clearly see two distinct optimization phases in the information plane, as discussed in the paper. During the first *empirical error minimization* (ERM) phase (until around epoch 1500), the information on the outputs $I_Y$ increases quickly, and then during the second *representation compression* phase (from around epoch 1500 onwards), the information on the inputs $I_X$ decreases. The evolution is not as smooth as shown in the paper, because it is the result of only one network, instead of average of multiple networks.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML

# %%
cmap = plt.cm.get_cmap('cool')

def make_animate(mi_xt_all, ax, title):
    def animate(i):
        title.set_text('Epoch %s' % str(epochs[i]).zfill(4))
        ax.plot(mi_xt_all[i,:], mi_ty_all[i,:], 'k-',alpha=0.2)
        if i > 0:
            for j in range(n_hidden_layers):
                ax.plot(mi_xt_all[(i-1):(i+1),j],mi_ty_all[(i-1):(i+1),j],'.-',c=cmap(j*.2))
    return animate
fig, ax = plt.subplots(figsize=(8,8))
#ax.set_xlim((5.5,7))
#ax.set_ylim((0.2,0.5))
ax.set_xlabel('I(X;T)')
ax.set_ylabel('I(T;Y)')
title = ax.set_title('')
plt.close(fig)
_ = list(map(make_animate(mi_xt_all, ax, title), range(mi_ty_all.shape[0])))
ax.set_title('Epoch 0000 - 2999. All inputs')

fig2, ax = plt.subplots(figsize=(8,8))
#ax.set_xlim((5.5,7))
#ax.set_ylim((0.2,0.5))
ax.set_xlabel('I(X rel;T)')
ax.set_ylabel('I(T;Y)')
title = ax.set_title('')
plt.close(fig2)
_ = list(map(make_animate(mi_xt_rel, ax, title), range(mi_ty_all.shape[0])))
ax.set_title('Epoch 0000 - 2999. Relevant Inputs')

fig3, ax = plt.subplots(figsize=(8,8))
#ax.set_xlim((5.5,7))
#ax.set_ylim((0.2,0.5))
ax.set_xlabel('I(X irrel;T)')
ax.set_ylabel('I(T;Y)')
title = ax.set_title('')
plt.close(fig3)
_ = list(map(make_animate(mi_xt_irrel, ax, title), range(mi_ty_all.shape[0])))
ax.set_title('Epoch 0000 - 2999. Irrelevant Inputs')
ax.legend()


fig # show full evolution process

# %%
fig2

# %%
fig3

# %% [markdown]
# ## More hidden layers

# %% [markdown]
# Finally, we try to use 5 hidden layers instead of 3. The number of neurons in the layers are 8, 7, 6, 5 and 3 respectively. Still, two optimzation phases are clearly seen in the information plane.

# %%
n_epochs = 3000
n_hidden_layers = 5
build_network([8,7,6,5,3]) # 5 hidden layers
mi_xt_all, mi_ty_all, epochs, mi_xt_rel, mi_xt_irrel = train_with_mi(n_epochs, n_hidden_layers)
# Out:
# Epoch    0:  Testing accuracy 0.5604 - Testing loss 0.9283
# Epoch  100:  Testing accuracy 0.6060 - Testing loss 0.6828
# Epoch  200:  Testing accuracy 0.6126 - Testing loss 0.6664
# Epoch  300:  Testing accuracy 0.6156 - Testing loss 0.6582
# Epoch  400:  Testing accuracy 0.6321 - Testing loss 0.6511
# Epoch  500:  Testing accuracy 0.6433 - Testing loss 0.6406
# Epoch  600:  Testing accuracy 0.6599 - Testing loss 0.6261
# Epoch  700:  Testing accuracy 0.6824 - Testing loss 0.5918
# Epoch  800:  Testing accuracy 0.7565 - Testing loss 0.5024
# Epoch  900:  Testing accuracy 0.7649 - Testing loss 0.4617
# Epoch 1000:  Testing accuracy 0.7781 - Testing loss 0.4403
# Epoch 1100:  Testing accuracy 0.7867 - Testing loss 0.4213
# Epoch 1200:  Testing accuracy 0.8003 - Testing loss 0.4025
# Epoch 1300:  Testing accuracy 0.8092 - Testing loss 0.3865
# Epoch 1400:  Testing accuracy 0.8202 - Testing loss 0.3749
# Epoch 1500:  Testing accuracy 0.8233 - Testing loss 0.3670
# Epoch 1600:  Testing accuracy 0.8265 - Testing loss 0.3611
# Epoch 1700:  Testing accuracy 0.8294 - Testing loss 0.3560
# Epoch 1800:  Testing accuracy 0.8369 - Testing loss 0.3502
# Epoch 1900:  Testing accuracy 0.8429 - Testing loss 0.3419
# Epoch 2000:  Testing accuracy 0.8548 - Testing loss 0.3296
# Epoch 2100:  Testing accuracy 0.8740 - Testing loss 0.3083
# Epoch 2200:  Testing accuracy 0.8904 - Testing loss 0.2819
# Epoch 2300:  Testing accuracy 0.9006 - Testing loss 0.2619
# Epoch 2400:  Testing accuracy 0.9022 - Testing loss 0.2586
# Epoch 2500:  Testing accuracy 0.9022 - Testing loss 0.2569
# Epoch 2600:  Testing accuracy 0.9022 - Testing loss 0.2557
# Epoch 2700:  Testing accuracy 0.9022 - Testing loss 0.2548
# Epoch 2800:  Testing accuracy 0.9022 - Testing loss 0.2541
# Epoch 2900:  Testing accuracy 0.9022 - Testing loss 0.2535

# %%
fig, ax = plt.subplots(figsize=(8,8))
#ax.set_xlim((5.5,7))
#ax.set_ylim((0.2,0.5))
ax.set_xlabel('I(X;T)')
ax.set_ylabel('I(T;Y)')
title = ax.set_title('')
plt.close(fig)
_ = list(map(make_animate(mi_xt_all, ax, title), range(mi_ty_all.shape[0])))
ax.set_title('Epoch 0000 - 2999. All inputs')

fig2, ax = plt.subplots(figsize=(8,8))
#ax.set_xlim((5.5,7))
#ax.set_ylim((0.2,0.5))
ax.set_xlabel('I(X rel;T)')
ax.set_ylabel('I(T;Y)')
title = ax.set_title('')
plt.close(fig2)
_ = list(map(make_animate(mi_xt_rel, ax, title), range(mi_ty_all.shape[0])))
ax.set_title('Epoch 0000 - 2999. Relevant Inputs')

fig3, ax = plt.subplots(figsize=(8,8))
#ax.set_xlim((5.5,7))
#ax.set_ylim((0.2,0.5))
ax.set_xlabel('I(X irrel;T)')
ax.set_ylabel('I(T;Y)')
title = ax.set_title('')
plt.close(fig3)
_ = list(map(make_animate(mi_xt_irrel, ax, title), range(mi_ty_all.shape[0])))
ax.set_title('Epoch 0000 - 2999. Irrelevant Inputs')



fig # show full evolution process

# %%
fig2

# %%
fig3
